# %% [markdown]
# # Hello

# %%
print('Hello Jupyter!')
# Out:
# Hello Jupyter!

# %%
x = "Hallo"

# %%
import filename
filename.sum_of_squares(3, 3)
# Out:
# 18

# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3, 4], [2, 1, 3, 6])
plt.ylabel('some numbers')
plt.show()
